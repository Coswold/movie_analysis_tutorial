# %%
import pandas as pd

# Load and plot passaenger time series

df = pd.read_csv('nuforc_reports.csv')

# %%
df
# Out:
#                                                   summary  \
# 0       Three saucer shaped ships.  High in the sky, m...
# 1       Tear-drop shaped silent craft with sectional f...
# 2       Green orb shot out of white light  ((NUFORC No...
# 3       Saw three circular orange lights traveling sou...
# 4       Light moving slowly thru the sky towards the W...
# 5       Bright pulsating white light brighter than Ven...
# 6                            ((HOAX??))  Loud boom heard.
# 7       Two erratic bright white lights seen in Southe...
# 8       There was only one UFO.  It was yellow orange-...
# 9       Not the only time lights followed me.First tim...
# 10      Two UFOs over Rockville, MD.  ((anonymous repo...
# 11                             Light above the tree line.
# 12      Bright falling object falls in a direct line t...
# 13      Friday march 10th 2017. There was a White ligh...
# 14      A series of objects, approx. 30-50, flying in ...
# ...

# %%
df['shape'].unique()
# Out:
# array(['disk', 'teardrop', 'light', 'circle', 'unknown', 'changing',
#        'oval', 'formation', 'cone', 'cigar', 'triangle', 'other',
#        'sphere', 'egg', 'rectangle', 'fireball', 'delta', 'pyramid',
#        'cylinder', 'chevron', nan, 'cross', 'flash', 'crescent',
#        'diamond', 'hexagon', 'flare', 'round', 'changed', 'dome'],
#       dtype=object)

# %%
sighted = df.groupby('state')['shape'].count()

# %%
df['state'].plot(kind='hist', bins=20)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-16-cc2726f82bb5> in <module>
# ----> 1 df['state'].plot(kind='hist', bins=20)
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/plotting/_core.py in __call__(self, kind, ax, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, label, secondary_y, **kwds)
#    2737                            colormap=colormap, table=table, yerr=yerr,
#    2738                            xerr=xerr, label=label, secondary_y=secondary_y,
# -> 2739                            **kwds)
#    2740     __call__.__doc__ = plot_series.__doc__
#    2741
#
# ...
